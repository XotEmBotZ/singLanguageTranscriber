# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time
import mediapipe as mp
from pprint import pprint
from mediapipe import solutions
from mediapipe.framework.formats import landmark_pb2
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import TensorBoard
from sklearn.metrics import multilabel_confusion_matrix, accuracy_score
from scipy import stats
# Out:
# 2023-12-01 10:14:02.130891: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-12-01 10:14:02.171931: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-01 10:14:02.171992: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-01 10:14:02.174827: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-01 10:14:02.183805: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-12-01 10:14:02.184503: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-01 10:14:03.767351: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
BaseOptions = mp.tasks.BaseOptions
VisionRunningMode = mp.tasks.vision.RunningMode

HandLandmarker = mp.tasks.vision.HandLandmarker
HandLandmarkerOptions = mp.tasks.vision.HandLandmarkerOptions

FaceLandmarker = mp.tasks.vision.FaceLandmarker
FaceLandmarkerOptions = mp.tasks.vision.FaceLandmarkerOptions


PoseLandmarker = mp.tasks.vision.PoseLandmarker
PoseLandmarkerOptions = mp.tasks.vision.PoseLandmarkerOptions

# %%
hand_model_path = 'models/hand_landmarkr_full.task'
face_model_path = 'models/face_landmarker.task'
pose_model_path = 'models/pose_landmarker_heavy.task'

# %%
handOptions = HandLandmarkerOptions(
    base_options=BaseOptions(model_asset_path=hand_model_path),
    running_mode=VisionRunningMode.VIDEO,
    num_hands=2)

faceOptions = FaceLandmarkerOptions(
    base_options=BaseOptions(model_asset_path=face_model_path),
    running_mode=VisionRunningMode.VIDEO)

poseOptions = PoseLandmarkerOptions(
    base_options=BaseOptions(model_asset_path=pose_model_path),
    running_mode=VisionRunningMode.VIDEO)

# %%
def initModels():
    handLandmarker=HandLandmarker.create_from_options(handOptions)
    faceLandmarker=FaceLandmarker.create_from_options(faceOptions)
    poseLandmarker=PoseLandmarker.create_from_options(poseOptions)
    return handLandmarker,faceLandmarker,poseLandmarker
handLandmarker=HandLandmarker.create_from_options(handOptions)
faceLandmarker=FaceLandmarker.create_from_options(faceOptions)
poseLandmarker=PoseLandmarker.create_from_options(poseOptions)
# initModels()

# %%
def draw_landmarks_on_image(rgb_image, pose_detection_result,hand_detection_result):
  pose_landmarks_list = pose_detection_result.pose_landmarks
  
  hand_landmarks_list = hand_detection_result.hand_landmarks
  handedness_list = hand_detection_result.handedness
  
  annotated_image = np.copy(rgb_image)

  MARGIN = 10  # pixels
  FONT_SIZE = 1
  FONT_THICKNESS = 1
  HANDEDNESS_TEXT_COLOR = (88, 205, 54) # vibrant green

  # Loop through the detected poses to visualize.
  for idx in range(len(pose_landmarks_list)):
    pose_landmarks = pose_landmarks_list[idx]

    # Draw the pose landmarks.
    pose_landmarks_proto = landmark_pb2.NormalizedLandmarkList()
    pose_landmarks_proto.landmark.extend([
        landmark_pb2.NormalizedLandmark(x=landmark.x, y=landmark.y, z=landmark.z) for landmark in pose_landmarks
    ])
    solutions.drawing_utils.draw_landmarks(
        annotated_image,
        pose_landmarks_proto,
        solutions.pose.POSE_CONNECTIONS,
        solutions.drawing_styles.get_default_pose_landmarks_style())
    
  # Loop through the detected hands to visualize.
  for idx in range(len(hand_landmarks_list)):
    hand_landmarks = hand_landmarks_list[idx]
    handedness = handedness_list[idx]

    # Draw the hand landmarks.
    hand_landmarks_proto = landmark_pb2.NormalizedLandmarkList()
    hand_landmarks_proto.landmark.extend([
        landmark_pb2.NormalizedLandmark(x=landmark.x, y=landmark.y, z=landmark.z) for landmark in hand_landmarks
    ])
    solutions.drawing_utils.draw_landmarks(
        annotated_image,
        hand_landmarks_proto,
        solutions.hands.HAND_CONNECTIONS,
        solutions.drawing_styles.get_default_hand_landmarks_style(),
        solutions.drawing_styles.get_default_hand_connections_style())

    # Get the top left corner of the detected hand's bounding box.
    height, width, _ = annotated_image.shape
    x_coordinates = [landmark.x for landmark in hand_landmarks]
    y_coordinates = [landmark.y for landmark in hand_landmarks]
    text_x = int(min(x_coordinates) * width)
    text_y = int(min(y_coordinates) * height) - MARGIN

    # Draw handedness (left or right hand) on the image.
    cv2.putText(annotated_image, f"{handedness[0].category_name}",
                (text_x, text_y), cv2.FONT_HERSHEY_DUPLEX,
                FONT_SIZE, HANDEDNESS_TEXT_COLOR, FONT_THICKNESS, cv2.LINE_AA)
  return annotated_image

# %%
def save_data(pose_landmarket_result, hand_landmarker_result, name=None,npReturn=False):
    
    if len(pose_landmarket_result.pose_landmarks) > 0:
        finalPoseData: np.ndarray = np.array([[i.x, i.y, i.z]
                                              for i in pose_landmarket_result.pose_landmarks[0]]).flatten()
    else:
        finalPoseData = np.zeros((99,))
    finalLeftHandData = np.zeros((63,))
    finalRightHandData = np.zeros((63,))
    for idx in range(len(hand_landmarker_result.hand_landmarks)):
        
        if hand_landmarker_result.handedness[idx][0].category_name == "Left":
            finalLeftHandData=np.array([[i.x, i.y, i.z] for i in hand_landmarker_result.hand_landmarks[[idx][0]]]).flatten()
        else:
            finalRightHandData = np.array([[i.x, i.y, i.z] for i in hand_landmarker_result.hand_landmarks[[idx][0]]]).flatten()

    if npReturn:
        return np.concatenate([ finalPoseData, finalLeftHandData, finalRightHandData])
    np.save(name, np.concatenate([ finalPoseData, finalLeftHandData, finalRightHandData]))

# %%
cap = cv2.VideoCapture(0)
prev_frame_time = 0
new_frame_time = 0
startTime=time.time()
handLandmarker, faceLandmarker, poseLandmarker = initModels()
while cap.isOpened():
    new_frame_time = time.time()

    ret, frame = cap.read()

    mp_image = mp.Image(image_format=mp.ImageFormat.SRGB,
                        data=cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
    
    hand_landmarker_result = handLandmarker.detect_for_video(
        mp_image,int((time.time()-startTime)*1000))
    pose_landmarket_result = poseLandmarker.detect_for_video(
        mp_image,int((time.time()-startTime)*1000))

    image = cv2.cvtColor(draw_landmarks_on_image(
        mp_image.numpy_view(), pose_landmarket_result,hand_landmarker_result), cv2.COLOR_RGB2BGR)

    # pprint(hand_landmarker_result.handedness)
    save_data(pose_landmarket_result, hand_landmarker_result, "testSave.npy")

    fps = 1/(new_frame_time-prev_frame_time)
    prev_frame_time = new_frame_time
    cv2.putText(image, f"{fps:1f}", (15, 50),
                cv2.FONT_HERSHEY_PLAIN, 2, (255, 255, 255), 3)
    cv2.imshow('OpenCV Feed', image)

    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# I0000 00:00:1701396782.263928    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701396782.265246   14765 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# I0000 00:00:1701396782.287445    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701396782.288465   14784 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# W0000 00:00:1701396782.288736    4809 face_landmarker_graph.cc:174] Sets FaceBlendshapesGraph acceleration to xnnpack by default.
# I0000 00:00:1701396782.316293    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701396782.317208   14803 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)

# %%
cv2.destroyAllWindows()

# %%
sign=['control','thankyou','iloveyou','please']

# %%
DATA_PATH = os.path.join('data')
actions = np.array(sign)
no_sequences = 50
sequence_length = 15

# %%
for action in actions:
    try:
        os.mkdir(DATA_PATH+f'/{action}')
    except:
        ...
    for i in range(no_sequences):
        try:
            os.mkdir(DATA_PATH+f'/{action}/{i}')
        except:
            ...

# %%
cap.release()
cv2.destroyAllWindows()

# %%
def collectData(action):
    for sequence in range(no_sequences):
        handLandmarker, faceLandmarker, poseLandmarker = initModels()
        startTime = time.time()
        for frame_num in range(sequence_length):
            ret, frame = cap.read()

            mp_image = mp.Image(image_format=mp.ImageFormat.SRGB,
                                data=cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))

            hand_landmarker_result = handLandmarker.detect_for_video(
                mp_image, int((time.time()-startTime)*1000))
            pose_landmarket_result = poseLandmarker.detect_for_video(
                mp_image, int((time.time()-startTime)*1000))

            image = cv2.cvtColor(draw_landmarks_on_image(
                mp_image.numpy_view(), pose_landmarket_result, hand_landmarker_result), cv2.COLOR_RGB2BGR)

            if frame_num == 0:
                cv2.putText(image, 'STARTING COLLECTION', (120, 200),
                            cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 4, cv2.LINE_AA)
                cv2.putText(image, 'Collecting frames for {} Video Number {} Frame No {}'.format(action, sequence, frame_num), (15, 12),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 1, cv2.LINE_AA)
                # Show to screen
                cv2.imshow('OpenCV Feed', image)
                cv2.waitKey(500)
            else:
                cv2.putText(image, 'Collecting frames for {} Video Number {} Frame No {}'.format(action, sequence, frame_num), (15, 12),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 1, cv2.LINE_AA)
                # Show to screen
                cv2.imshow('OpenCV Feed', image)

            npy_path = os.path.join(
                DATA_PATH, action, str(sequence), str(frame_num))
            save_data(pose_landmarket_result,
                      hand_landmarker_result, npy_path, )
            # Break gracefully
            cv2.imshow('OpenCV Feed', image)
            if cv2.waitKey(10) & 0xFF == ord('q'):
                break

# %%
cap = cv2.VideoCapture(0)
collectData('sorry')
cap.release()
cv2.destroyAllWindows()
# Out:
# I0000 00:00:1701398972.713167    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701398972.714609   68226 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# I0000 00:00:1701398972.743279    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701398972.744499   68245 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# W0000 00:00:1701398972.744893    4809 face_landmarker_graph.cc:174] Sets FaceBlendshapesGraph acceleration to xnnpack by default.
# I0000 00:00:1701398972.764027    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701398972.765157   68264 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# I0000 00:00:1701398977.039909    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701398977.040977   68284 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# I0000 00:00:1701398977.062876    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701398977.063875   68303 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# W0000 00:00:1701398977.064123    4809 face_landmarker_graph.cc:174] Sets FaceBlendshapesGraph acceleration to xnnpack by default.
# I0000 00:00:1701398977.080260    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701398977.081195   68322 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# I0000 00:00:1701398981.141864    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701398981.143112   68350 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# I0000 00:00:1701398981.162947    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701398981.163938   68369 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# W0000 00:00:1701398981.164217    4809 face_landmarker_graph.cc:174] Sets FaceBlendshapesGraph acceleration to xnnpack by default.
# I0000 00:00:1701398981.181045    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701398981.182037   68388 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# I0000 00:00:1701398985.124368    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701398985.125438   68416 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# I0000 00:00:1701398985.145804    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701398985.146737   68435 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# W0000 00:00:1701398985.146986    4809 face_landmarker_graph.cc:174] Sets FaceBlendshapesGraph acceleration to xnnpack by default.
# I0000 00:00:1701398985.162720    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701398985.163674   68454 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# I0000 00:00:1701398989.074896    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701398989.076158   68482 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# I0000 00:00:1701398989.099918    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701398989.101314   68501 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# W0000 00:00:1701398989.103235    4809 face_landmarker_graph.cc:174] Sets FaceBlendshapesGraph acceleration to xnnpack by default.
# I0000 00:00:1701398989.116978    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701398989.118153   68520 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# I0000 00:00:1701398992.991251    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701398992.992245   68549 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# I0000 00:00:1701398993.011729    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701398993.012724   68568 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# W0000 00:00:1701398993.012975    4809 face_landmarker_graph.cc:174] Sets FaceBlendshapesGraph acceleration to xnnpack by default.
# I0000 00:00:1701398993.022736    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701398993.023743   68587 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# I0000 00:00:1701398996.982768    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701398996.983930   68606 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# I0000 00:00:1701398997.009801    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701398997.010746   68625 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# W0000 00:00:1701398997.011052    4809 face_landmarker_graph.cc:174] Sets FaceBlendshapesGraph acceleration to xnnpack by default.
# I0000 00:00:1701398997.021219    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701398997.022295   68644 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# I0000 00:00:1701399001.033649    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701399001.039278   68672 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# I0000 00:00:1701399001.060480    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701399001.061620   68691 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# W0000 00:00:1701399001.061925    4809 face_landmarker_graph.cc:174] Sets FaceBlendshapesGraph acceleration to xnnpack by default.
# I0000 00:00:1701399001.078677    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701399001.079622   68710 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# I0000 00:00:1701399005.074675    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701399005.075762   68738 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# I0000 00:00:1701399005.095906    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701399005.096918   68757 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# W0000 00:00:1701399005.097217    4809 face_landmarker_graph.cc:174] Sets FaceBlendshapesGraph acceleration to xnnpack by default.
# I0000 00:00:1701399005.112722    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701399005.113692   68776 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# I0000 00:00:1701399009.239927    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701399009.241099   68804 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# I0000 00:00:1701399009.261368    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701399009.262304   68823 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# W0000 00:00:1701399009.262533    4809 face_landmarker_graph.cc:174] Sets FaceBlendshapesGraph acceleration to xnnpack by default.
# I0000 00:00:1701399009.278519    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701399009.279427   68842 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# I0000 00:00:1701399013.254191    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701399013.255225   68870 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# I0000 00:00:1701399013.275893    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701399013.276822   68889 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# W0000 00:00:1701399013.277101    4809 face_landmarker_graph.cc:174] Sets FaceBlendshapesGraph acceleration to xnnpack by default.
# I0000 00:00:1701399013.293278    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701399013.294241   68908 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# I0000 00:00:1701399017.456472    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701399017.457511   68942 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# I0000 00:00:1701399017.477307    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701399017.478298   68961 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# W0000 00:00:1701399017.478547    4809 face_landmarker_graph.cc:174] Sets FaceBlendshapesGraph acceleration to xnnpack by default.
# I0000 00:00:1701399017.494349    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701399017.495336   68980 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# I0000 00:00:1701399021.376718    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701399021.377880   68999 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# I0000 00:00:1701399021.397797    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701399021.398808   69018 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# W0000 00:00:1701399021.399091    4809 face_landmarker_graph.cc:174] Sets FaceBlendshapesGraph acceleration to xnnpack by default.
# I0000 00:00:1701399021.415077    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701399021.416073   69037 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# I0000 00:00:1701399025.457570    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701399025.458656   69065 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# I0000 00:00:1701399025.479215    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701399025.480135   69084 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# W0000 00:00:1701399025.480377    4809 face_landmarker_graph.cc:174] Sets FaceBlendshapesGraph acceleration to xnnpack by default.
# I0000 00:00:1701399025.496461    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701399025.497423   69103 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# I0000 00:00:1701399029.505983    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701399029.507117   69131 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# I0000 00:00:1701399029.528009    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701399029.529063   69150 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# W0000 00:00:1701399029.529327    4809 face_landmarker_graph.cc:174] Sets FaceBlendshapesGraph acceleration to xnnpack by default.
# I0000 00:00:1701399029.545841    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701399029.546789   69169 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# I0000 00:00:1701399033.445379    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701399033.446637   69197 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# I0000 00:00:1701399033.467008    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701399033.468127   69216 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# W0000 00:00:1701399033.468535    4809 face_landmarker_graph.cc:174] Sets FaceBlendshapesGraph acceleration to xnnpack by default.
# I0000 00:00:1701399033.484368    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701399033.486402   69235 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# I0000 00:00:1701399037.444885    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701399037.446108   69263 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# I0000 00:00:1701399037.466500    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701399037.467774   69282 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# W0000 00:00:1701399037.468085    4809 face_landmarker_graph.cc:174] Sets FaceBlendshapesGraph acceleration to xnnpack by default.
# I0000 00:00:1701399037.494987    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701399037.495923   69301 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# I0000 00:00:1701399041.408580    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701399041.409610   69320 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# I0000 00:00:1701399041.429413    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701
4809 face_landmarker_graph.cc:174] Sets FaceBlendshapesGraph acceleration to xnnpack by default.
# I0000 00:00:1701397031.660906    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701397031.667428   17921 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# I0000 00:00:1701397035.687276    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701397035.688302   17950 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# I0000 00:00:1701397035.708254    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701397035.709204   17969 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# W0000 00:00:1701397035.709463    4809 face_landmarker_graph.cc:174] Sets FaceBlendshapesGraph acceleration to xnnpack by default.
# I0000 00:00:1701397035.725727    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701397035.726747   17988 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# I0000 00:00:1701397039.634034    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701397039.635732   18016 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# I0000 00:00:1701397039.655829    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701397039.656827   18035 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# W0000 00:00:1701397039.657108    4809 face_landmarker_graph.cc:174] Sets FaceBlendshapesGraph acceleration to xnnpack by default.
# I0000 00:00:1701397039.673398    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701397039.674334   18054 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# ...
# I0000 00:00:1701397670.397798   27213 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# W0000 00:00:1701397670.398069    4809 face_landmarker_graph.cc:174] Sets FaceBlendshapesGraph acceleration to xnnpack by default.
# I0000 00:00:1701397670.414467    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701397670.415422   27232 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# I0000 00:00:1701397674.420538    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701397674.421663   27260 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# I0000 00:00:1701397674.441931    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701397674.443021   27279 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# W0000 00:00:1701397674.443299    4809 face_landmarker_graph.cc:174] Sets FaceBlendshapesGraph acceleration to xnnpack by default.
# I0000 00:00:1701397674.459493    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701397674.460500   27298 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# I0000 00:00:1701397678.309385    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701397678.310550   27326 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# I0000 00:00:1701397678.330944    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701397678.331938   27345 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# W0000 00:00:1701397678.332220    4809 face_landmarker_graph.cc:174] Sets FaceBlendshapesGraph acceleration to xnnpack by default.
# I0000 00:00:1701397678.349336    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701397678.350340   27364 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# I0000 00:00:1701397682.194611    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701397682.195926   27383 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# I0000 00:00:1701397682.216075    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701397682.217137   27402 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# W0000 00:00:1701397682.217416    4809 face_landmarker_graph.cc:174] Sets FaceBlendshapesGraph acceleration to xnnpack by default.
# I0000 00:00:1701397682.234518    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701397682.235615   27421 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# I0000 00:00:1701397686.044815    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701397686.046098   27450 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# I0000 00:00:1701397686.066288    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701397686.067311   27469 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# W0000 00:00:1701397686.067599    4809 face_landmarker_graph.cc:174] Sets FaceBlendshapesGraph acceleration to xnnpack by default.
# I0000 00:00:1701397686.084047    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701397686.085126   27488 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# I0000 00:00:1701397689.909198    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701397689.910297   27516 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# I0000 00:00:1701397689.930300    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701397689.931626   27535 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# W0000 00:00:1701397689.931963    4809 face_landmarker_graph.cc:174] Sets FaceBlendshapesGraph acceleration to xnnpack by default.
# I0000 00:00:1701397689.948603    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701397689.949563   27554 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# I0000 00:00:1701397693.839136    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701397693.840365   27582 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# I0000 00:00:1701397693.860549    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701397693.861591   27601 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# W0000 00:00:1701397693.861881    4809 face_landmarker_graph.cc:174] Sets FaceBlendshapesGraph acceleration to xnnpack by default.
# I0000 00:00:1701397693.878848    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701397693.879911   27620 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# I0000 00:00:1701397697.755242    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701397697.756251   27648 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# I0000 00:00:1701397697.770365    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701397697.771393   27667 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# W0000 00:00:1701397697.771651    4809 face_landmarker_graph.cc:174] Sets FaceBlendshapesGraph acceleration to xnnpack by default.
# I0000 00:00:1701397697.782071    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701397697.788021   27686 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# I0000 00:00:1701397701.777936    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701397701.779014   27705 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# I0000 00:00:1701397701.793537    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701397701.794912   27724 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# W0000 00:00:1701397701.795389    4809 face_landmarker_graph.cc:174] Sets FaceBlendshapesGraph acceleration to xnnpack by default.
# I0000 00:00:1701397701.811905    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701397701.812858   27743 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# I0000 00:00:1701397705.710278    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701397705.711433   27771 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# I0000 00:00:1701397705.731368    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701397705.732342   27790 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# W0000 00:00:1701397705.732604    4809 face_landmarker_graph.cc:174] Sets FaceBlendshapesGraph acceleration to xnnpack by default.
# I0000 00:00:1701397705.748883    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701397705.749834   27809 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# I0000 00:00:1701397709.677643    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701397709.678835   27837 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# I0000 00:00:1701397709.700558    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701397709.701629   27856 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# W0000 00:00:1701397709.701962    4809 face_landmarker_graph.cc:174] Sets FaceBlendshapesGraph acceleration to xnnpack by default.
# I0000 00:00:1701397709.717728    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701397709.718785   27875 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# I0000 00:00:1701397713.490707    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701397713.491931   27904 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# I0000 00:00:1701397713.512023    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701397713.513105   27923 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# W0000 00:00:1701397713.513563    4809 face_landmarker_graph.cc:174] Sets FaceBlendshapesGraph acceleration to xnnpack by default.
# I0000 00:00:1701397713.530020    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701397713.531003   27942 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# I0000 00:00:1701397717.342815    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701397717.343849   27963 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# I0000 00:00:1701397717.364322    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701397717.365400   27982 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# W0000 00:00:1701397717.365691    4809 face_landmarker_graph.cc:174] Sets FaceBlendshapesGraph acceleration to xnnpack by default.
# I0000 00:00:1701397717.382077    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701397717.383047   28010 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# I0000 00:00:1701397721.157908    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701397721.159928   28029 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# I0000 00:00:1701397721.179724    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701397721.180725   28048 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# W0000 00:00:1701397721.180997    4809 face_landmarker_graph.cc:174] Sets FaceBlendshapesGraph acceleration to xnnpack by default.
# I0000 00:00:1701397721.191269    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701397721.192269   28067 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# I0000 00:00:1701397725.016852    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701397725.018509   28095 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# I0000 00:00:1701397725.043887    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701397725.045011   28114 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# W0000 00:00:1701397725.045284    4809 face_landmarker_graph.cc:174] Sets FaceBlendshapesGraph acceleration to xnnpack by default.
# I0000 00:00:1701397725.061588    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701397725.063022   28133 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# I0000 00:00:1701397728.826946    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701397728.828108   28161 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# I0000 00:00:1701397728.848035    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701397728.849120   28180 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# W0000 00:00:1701397728.849388    4809 face_landmarker_graph.cc:174] Sets FaceBlendshapesGraph acceleration to xnnpack by default.
# I0000 00:00:1701397728.872571    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701397728.876318   28199 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)

# %%
label_map = {label: num for num, label in enumerate(actions)}
label_map
# Out:
# {'control': 0, 'thankyou': 1, 'iloveyou': 2, 'please': 3}

# %%
sequences, labels = [], []
for action in actions:
    for sequence in np.array(os.listdir(os.path.join(DATA_PATH, action))).astype(int):
        window = []
        for frame_num in range(sequence_length):
            res = np.load(os.path.join(DATA_PATH, action, str(
                sequence), "{}.npy".format(frame_num)))
            window.append(res)
        sequences.append(window)
        labels.append(label_map[action])
np.array(sequences).shape, np.array(labels).shape
# Out:
# ((200, 15, 225), (200,))

# %%
X = np.array(sequences)
Y = to_categorical(labels).astype(int)
X.shape,Y.shape
# Out:
# ((200, 15, 225), (200, 4))

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.1)

# %%
X_train.shape[1:],actions.shape[0]
# Out:
# ((15, 225), 4)

# %%
log_dir = os.path.join('logs')
tb_callback = TensorBoard(log_dir=log_dir)

# %%
model = Sequential()
model.add(LSTM(64, return_sequences=True,
          activation='relu', input_shape=X_train.shape[1:]))
model.add(LSTM(128, return_sequences=True, activation='relu'))
model.add(LSTM(128, return_sequences=True, activation='relu'))
model.add(LSTM(64, return_sequences=False, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(actions.shape[0], activation='softmax'))

# %%
model.compile(optimizer='Adam', loss='categorical_crossentropy',
              metrics=['categorical_accuracy'])

# %%
model.fit(X_train, Y_train, epochs=2000, callbacks=[tb_callback])
# Out:
# Epoch 1/2000
# 6/6 [==============================] - 8s 27ms/step - loss: 1.3787 - categorical_accuracy: 0.4167
# Epoch 2/2000
# 6/6 [==============================] - 0s 27ms/step - loss: 1.1944 - categorical_accuracy: 0.4722
# Epoch 3/2000
# 6/6 [==============================] - 0s 29ms/step - loss: 0.7726 - categorical_accuracy: 0.7000
# Epoch 4/2000
# 6/6 [==============================] - 0s 31ms/step - loss: 0.6343 - categorical_accuracy: 0.8222
# Epoch 5/2000
# 6/6 [==============================] - 0s 27ms/step - loss: 0.5382 - categorical_accuracy: 0.8556
# Epoch 6/2000
# 6/6 [==============================] - 0s 27ms/step - loss: 0.3487 - categorical_accuracy: 0.9056
# Epoch 7/2000
# 6/6 [==============================] - 0s 27ms/step - loss: 0.4040 - categorical_accuracy: 0.9333
# Epoch 8/2000
# 6/6 [==============================] - 0s 29ms/step - loss: 0.2493 - categorical_accuracy: 0.9611
# Epoch 9/2000
# 6/6 [==============================] - 0s 28ms/step - loss: 0.2080 - categorical_accuracy: 0.9444
# Epoch 10/2000
# 6/6 [==============================] - 0s 27ms/step - loss: 0.0821 - categorical_accuracy: 0.9833
# Epoch 11/2000
# 6/6 [==============================] - 0s 27ms/step - loss: 0.6244 - categorical_accuracy: 0.9056
# Epoch 12/2000
# 6/6 [==============================] - 0s 27ms/step - loss: 0.4819 - categorical_accuracy: 0.9000
# Epoch 13/2000
# 6/6 [==============================] - 0s 27ms/step - loss: 0.2719 - categorical_accuracy: 0.9667
# Epoch 14/2000
# 6/6 [==============================] - 0s 27ms/step - loss: 0.1749 - categorical_accuracy: 0.9667
# Epoch 15/2000
# 6/6 [==============================] - 0s 28ms/step - loss: 0.0785 - categorical_accuracy: 0.9833
# Epoch 16/2000
# 6/6 [==============================] - 0s 27ms/step - loss: 0.1165 - categorical_accuracy: 0.9500
# Epoch 17/2000
# 6/6 [==============================] - 0s 27ms/step - loss: 0.0939 - categorical_accuracy: 0.9833
# Epoch 18/2000
# 6/6 [==============================] - 0s 28ms/step - loss: 0.7415 - categorical_accuracy: 0.8722
# Epoch 19/2000
# 6/6 [==============================] - 0s 29ms/step - loss: 0.3454 - categorical_accuracy: 0.9167
# Epoch 20/2000
# 6/6 [==============================] - 0s 24ms/step - loss: 0.2623 - categorical_accuracy: 0.9611
# Epoch 21/2000
# 6/6 [==============================] - 0s 27ms/step - loss: 0.2156 - categorical_accuracy: 0.9889
# Epoch 22/2000
# 6/6 [==============================] - 0s 29ms/step - loss: 0.0749 - categorical_accuracy: 0.9889
# Epoch 23/2000
# 6/6 [==============================] - 0s 29ms/step - loss: 0.0633 - categorical_accuracy: 0.9833
# Epoch 24/2000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/xotembotz/personalProjects/schoolSignLanguageDetection/try1.ipynb Cell 25 line 1
# ----> <a href='vscode-notebook-cell:/home/xotembotz/personalProjects/schoolSignLanguageDetection/try1.ipynb#X31sZmlsZQ%3D%3D?line=0'>1</a> model.fit(X_train, Y_train, epochs=2000, callbacks=[tb_callback])
#
# File ~/personalProjects/schoolSignLanguageDetection/env/lib64/python3.11/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/personalProjects/schoolSignLanguageDetection/env/lib64/python3.11/site-packages/keras/src/engine/training.py:1807, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1799 with tf.profiler.experimental.Trace(
#    1800     "train",
#    1801     epoch_num=epoch,
#    (...)
#    1804     _r=1,
#    1805 ):
#    1806     callbacks.on_train_batch_begin(step)
# -> 1807     tmp_logs = self.train_function(iterator)
#    1808     if data_handler.should_sync:
#    1809         context.async_wait()
#
# File ~/personalProjects/schoolSignLanguageDetection/env/lib64/python3.11/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/personalProjects/schoolSignLanguageDetection/env/lib64/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:832, in Function.__call__(self, *args, **kwds)
#     829 compiler = "xla" if self._jit_compile else "nonXla"
#     831 with OptionalXlaContext(self._jit_compile):
# --> 832   result = self._call(*args, **kwds)
#     834 new_tracing_count = self.experimental_get_tracing_count()
#     835 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/personalProjects/schoolSignLanguageDetection/env/lib64/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:868, in Function._call(self, *args, **kwds)
#     865   self._lock.release()
#     866   # In this case we have created variables on the first call, so we run the
#     867   # defunned version which is guaranteed to never create variables.
# --> 868   return tracing_compilation.call_function(
#     869       args, kwds, self._no_variable_creation_config
#     870   )
#     871 elif self._variable_creation_config is not None:
#     872   # Release the lock early so that multiple threads can perform the call
#     873   # in parallel.
#     874   self._lock.release()
#
# File ~/personalProjects/schoolSignLanguageDetection/env/lib64/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File ~/personalProjects/schoolSignLanguageDetection/env/lib64/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py:1323, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1319 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1320 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1321     and executing_eagerly):
#    1322   # No tape is watching; skip to running the function.
# -> 1323   return self._inference_function.call_preflattened(args)
#    1324 forward_backward = self._select_forward_and_backward_functions(
#    1325     args,
#    1326     possible_gradient_type,
#    1327     executing_eagerly)
#    1328 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/personalProjects/schoolSignLanguageDetection/env/lib64/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File ~/personalProjects/schoolSignLanguageDetection/env/lib64/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File ~/personalProjects/schoolSignLanguageDetection/env/lib64/python3.11/site-packages/tensorflow/python/eager/context.py:1486, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1484 cancellation_context = cancellation.context()
#    1485 if cancellation_context is None:
# -> 1486   outputs = execute.execute(
#    1487       name.decode("utf-8"),
#    1488       num_outputs=num_outputs,
#    1489       inputs=tensor_inputs,
#    1490       attrs=attrs,
#    1491       ctx=self,
#    1492   )
#    1493 else:
#    1494   outputs = execute.execute_with_cancellation(
#    1495       name.decode("utf-8"),
#    1496       num_outputs=num_outputs,
#    (...)
#    1500       cancellation_manager=cancellation_context,
#    1501   )
#
# File ~/personalProjects/schoolSignLanguageDetection/env/lib64/python3.11/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
res = model.predict(X_test)
actions[np.argmax(res[4])], actions[np.argmax(Y_test[4])]
# Out:
# 1/1 [==============================] - 1s 785ms/step
# ('iloveyou', 'iloveyou')

# %%
yhat = model.predict(X_test)
ytrue = np.argmax(Y_test, axis=1).tolist()
yhat = np.argmax(yhat, axis=1).tolist()
multilabel_confusion_matrix(ytrue, yhat)
# Out:
# 1/1 [==============================] - 0s 27ms/step
# array([[[17,  0],
#         [ 0,  3]],
#
#        [[13,  0],
#         [ 1,  6]],
#
#        [[13,  1],
#         [ 0,  6]],
#
#        [[16,  0],
#         [ 0,  4]]])

# %%
accuracy_score(ytrue, yhat)
# Out:
# 0.95

# %%
np.expand_dims(X_test[0], axis=0)
# Out:
# array([[[ 0.61671913,  0.44044334, -0.6442681 , ...,  0.        ,
#           0.        ,  0.        ],
#         [ 0.61242396,  0.44335321, -0.55908298, ...,  0.        ,
#           0.        ,  0.        ],
#         [ 0.61338311,  0.44591859, -0.5828802 , ...,  0.        ,
#           0.        ,  0.        ],
#         ...,
#         [ 0.61112583,  0.42927632, -0.32872173, ...,  0.51288551,
#           0.56761646, -0.03853079],
#         [ 0.61660713,  0.42383578, -0.48927504, ...,  0.49429321,
#           0.57958066, -0.01583199],
#         [ 0.62080556,  0.42483413, -0.71497381, ...,  0.48863906,
#           0.59082407, -0.07455964]]])

# %%
X_test[0].shape,concatArray.shape
# Out:
# ((15, 225), (1659,))

# %%
model.predict(X_test)
# Out:
# 1/1 [==============================] - 0s 20ms/step
# array([[8.4433169e-26, 9.9999994e-01, 2.3078373e-12, 1.7069017e-14],
#        [9.9999994e-01, 2.1851581e-12, 1.3337194e-11, 5.1818697e-12],
#        [1.6653500e-17, 5.7626761e-11, 9.9999994e-01, 1.6637562e-17],
#        [9.5152330e-10, 3.8189318e-09, 5.6610895e-14, 9.9999994e-01],
#        [5.8765913e-15, 4.3612984e-09, 9.9999994e-01, 1.8473335e-14],
#        [9.9999994e-01, 4.4894303e-08, 2.4756556e-08, 1.2914426e-08],
#        [4.1091940e-15, 9.9999994e-01, 1.9548370e-08, 5.8777673e-08],
#        [7.8303637e-17, 9.9734332e-11, 9.9999994e-01, 4.3736761e-17],
#        [3.5306847e-26, 9.9999994e-01, 2.2525452e-12, 4.7400214e-15],
#        [6.9825840e-10, 4.1063059e-10, 1.0505851e-14, 9.9999994e-01],
#        [3.8171383e-10, 5.8445926e-10, 6.8976637e-15, 9.9999994e-01],
#        [2.9709948e-09, 2.8704417e-08, 3.7814939e-13, 9.9999994e-01],
#        [6.2568323e-10, 1.3436660e-09, 2.0010854e-14, 9.9999994e-01],
#        [4.3836480e-17, 2.3079982e-10, 9.9999994e-01, 1.0027421e-16],
#        [7.4319982e-22, 9.9999994e-01, 9.4378727e-10, 6.1149653e-12],
#        [3.3015682e-10, 1.8902756e-11, 1.4691240e-15, 9.9999994e-01],
#        [1.0000000e+00, 1.1715048e-11, 1.1969718e-10, 4.9876374e-11],
#        [1.0000000e+00, 5.9594750e-08, 3.1857976e-08, 1.6332654e-08],
#        [1.0000000e+00, 3.1548385e-11, 8.6105366e-11, 2.5824246e-11],
#        [3.5999671e-17, 6.1130323e-11, 1.0000000e+00, 1.3003150e-17]],
#       dtype=float32)

# %%
colors = [(245, 117, 16), (117, 245, 16), (16, 117, 245)]


def prob_viz(res, actions, input_frame, colors):
    output_frame = input_frame.copy()
    for num, prob in enumerate(res):
        cv2.rectangle(output_frame, (0, 60+num*40),
                      (int(prob*100), 90+num*40), colors[num], -1)
        cv2.putText(output_frame, actions[num], (0, 85+num*40),
                    cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)

    return output_frame

# %%
try:
    # 1. New detection variables
    sequence = []
    sentence = []
    predictions = []
    threshold = 0.5
    predict= predictF = "Not init"
    cap = cv2.VideoCapture(0)
    prev_frame_time = 0
    new_frame_time = 0
    startTime = time.time()
    handLandmarker, faceLandmarker, poseLandmarker = initModels()
    while cap.isOpened():
        new_frame_time = time.time()

        ret, frame = cap.read()

        mp_image = mp.Image(image_format=mp.ImageFormat.SRGB,
                            data=cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))

        hand_landmarker_result = handLandmarker.detect_for_video(
            mp_image, int((time.time()-startTime)*1000))
        pose_landmarket_result = poseLandmarker.detect_for_video(
            mp_image, int((time.time()-startTime)*1000))

        image = cv2.cvtColor(draw_landmarks_on_image(
            mp_image.numpy_view(), pose_landmarket_result, hand_landmarker_result), cv2.COLOR_RGB2BGR)

        # pprint(hand_landmarker_result.handedness)
        concatArray=save_data( pose_landmarket_result,
                hand_landmarker_result, npReturn=True)
        sequence.append(concatArray)
        
        if len(sequence)>15:
            predict = model.predict(np.expand_dims(sequence[-15:], axis=0))
            predictF=actions[np.argmax(predict)]
            cv2.putText(image, f"{(predict[0][0])}", (15, 410),
                        cv2.FONT_HERSHEY_PLAIN, 2, (255, 255, 255), 3)
            cv2.putText(image, f"{predict[0][1]}", (15, 440),
                        cv2.FONT_HERSHEY_PLAIN, 2, (255, 255, 255), 3)
            cv2.putText(image, f"{predict[0][2]}", (15, 470),
                        cv2.FONT_HERSHEY_PLAIN, 2, (255, 255, 255), 3)

        

        fps = 1/(new_frame_time-prev_frame_time)
        prev_frame_time = new_frame_time
        # cv2.putText(image, f"{fps:1f}", (15, 50),
        #             cv2.FONT_HERSHEY_PLAIN, 2, (255, 255, 255), 3)
        cv2.putText(image, f"{predictF}", (15, 50),
                    cv2.FONT_HERSHEY_PLAIN, 2, (255, 255, 255), 3)
        cv2.imshow('OpenCV Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
except Exception as e:
    cap.release()
    cv2.destroyAllWindows()
    raise e
# Out:
# I0000 00:00:1701399529.015696    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701399529.017117   84330 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# I0000 00:00:1701399529.037522    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701399529.038567   84349 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# W0000 00:00:1701399529.038881    4809 face_landmarker_graph.cc:174] Sets FaceBlendshapesGraph acceleration to xnnpack by default.
# I0000 00:00:1701399529.055954    4809 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1701399529.056923   84368 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.2.1), renderer: AMD Radeon Graphics (renoir, LLVM 16.0.6, DRM 3.54, 6.5.12-300.fc39.x86_64)
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step

# %%
model.save("model2-please")
# Out:
# INFO:tensorflow:Assets written to: model2-please/assets
# INFO:tensorflow:Assets written to: model2-please/assets
